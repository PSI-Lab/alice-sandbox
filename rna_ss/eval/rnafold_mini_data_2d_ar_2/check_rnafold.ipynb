# %%
import numpy as np
import pandas as pd

# %%
from utils import forna_url
# Out:
# Using TensorFlow backend.

# %%
df_rfam = pd.read_pickle('result/prediction.rfam.rnafold.pkl')

# %%
df_rfam.describe()
# Out:
#           ens_div   f_measure          fe         len      mfe_freq  \
# count  151.000000  142.000000  151.000000  151.000000  1.510000e+02
# mean    21.908609    0.659045  -47.071523  136.298013  1.363256e-01
# std     23.867984    0.256173   41.805627  102.036451  1.860683e-01
# min      0.290000    0.082192 -243.200000   23.000000  6.975520e-09
# 25%      5.845000    0.455164  -54.250000   67.000000  8.352240e-03
# 50%     13.780000    0.713164  -35.900000  104.000000  6.153330e-02
# 75%     29.790000    0.866460  -20.150000  158.500000  1.572485e-01
# max    137.480000    1.000000   -1.800000  568.000000  8.406150e-01
#
#               ppv  sensitivity
# count  151.000000   151.000000
# mean     0.573774     0.695547
# std      0.295790     0.302021
# min      0.000000     0.000000
# 25%      0.348573     0.506250
# 50%      0.574468     0.800000
# 75%      0.792892     0.986726
# max      1.000000     1.000000

# %%
df_stest = pd.read_pickle('result/prediction.s_test.rnafold.pkl')

# %%
df_stest.describe()
# Out:
#           ens_div   f_measure          fe         len      mfe_freq  \
# count  974.000000  922.000000  974.000000  974.000000  9.740000e+02
# mean    35.270349    0.659745  -65.214476  193.677618  2.192764e-01
# std     42.550360    0.246695   65.769438  191.695820  2.866980e-01
# min      0.010000    0.019868 -287.100000   10.000000  6.696790e-11
# 25%      2.882500    0.450248 -119.575000   41.000000  4.918003e-05
# 50%     13.225000    0.686415  -33.550000   98.000000  7.848920e-02
# 75%     64.197500    0.880000  -12.225000  353.750000  3.646010e-01
# max    221.230000    1.000000    0.000000  689.000000  9.952370e-01
#
#               ppv  sensitivity
# count  954.000000   974.000000
# mean     0.617139     0.653480
# std      0.277538     0.285953
# min      0.000000     0.000000
# 25%      0.407582     0.458983
# 50%      0.631174     0.677545
# 75%      0.857143     0.905494
# max      1.000000     1.000000
